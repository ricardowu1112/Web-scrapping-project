# %%
from collections import Counter
def word_count(fname):
        with open('/Users/kaholi3/Downloads/data-1/best_comments.csv', 'r', encoding= 'latin1') as f:
                return Counter(f.read().split())

print("Number of words in the file :",word_count("test.txt"))
# Out:
# Number of words in the file : Counter({'and': 760, 'the': 702, 'I': 658, 'a': 494, 'to': 449, 'was': 337, 'my': 286, 'for': 275, 'of': 274, 'with': 203, 'is': 201, 'in': 194, 'have': 154, 'it': 153, 'from': 144, 'that': 130, 'The': 120, 'you': 115, 'are': 114, 'on': 113, 'very': 113, 'order': 111, 'they': 111, 'this': 102, 'be': 101, 'me': 100, 'customer': 97, 'but': 96, 'as': 95, 'an': 91, 'had': 87, 'quality': 85, 'will': 85, 'service': 83, 'great': 82, 'so': 79, 'not': 70, 'ordered': 66, 'at': 66, 'been': 60, 'were': 58, 'their': 57, 'made': 55, 'would': 55, 'am': 54, 'them': 52, 'out': 52, 'received': 49, 'fit': 48, 'jacket': 46, 'like': 46, 'more': 46, 'just': 45, 'shirt': 45, 'time': 43, 'recommend': 42, 'when': 42, 'all': 42, 'love': 41, 'your': 41, 'size': 40, 'definitely': 40, 'good': 40, 'has': 40, 'experience': 38, 'some': 37, 'than': 37, 'shipping': 36, 'always': 36, 'about': 35, 'what': 35, 'if': 33, 'first': 32, 'one': 32, 'clothing': 32, 'fast': 31, 'They': 31, 'new': 
# ...

# %% [markdown]
# ### TOP 10 keywords from best comments
#
# 'Order' #111
# 'Quality' #85
# 'Service' #60
# 'Received' #49
# 'Fit' #48
# 'Time' #43
# 'Size' #40
# 'Experience' #38
# 'Shipping' #36
# 'Fast' #31

# %%
from collections import Counter
def word_count(fname):
        with open('/Users/kaholi3/Downloads/data-1/worst_comments.csv', 'r', encoding= 'latin1') as f:
                return Counter(f.read().split())

print("Number of words in the file :",word_count("test.txt"))
# Out:
# Number of words in the file : Counter({'the': 686, 'I': 582, 'and': 572, 'to': 494, 'a': 461, 'of': 240, 'is': 223, 'my': 222, 'they': 209, 'was': 198, 'for': 191, 'it': 176, 'that': 166, 'on': 159, 'have': 156, 'in': 153, 'with': 135, 'from': 134, 'not': 131, 'this': 120, 'you': 115, 'order': 112, 'but': 103, 'them': 98, 'be': 95, 'are': 92, 'their': 92, 'me': 88, 'no': 86, 'The': 77, 'would': 75, 'so': 71, 'as': 69, 'will': 68, 'customer': 68, 'They': 66, 'had': 66, 'just': 64, 'ordered': 63, 'received': 62, 'like': 60, 'get': 59, 'or': 58, 'an': 58, 'at': 57, 'company': 55, 'if': 53, 'service': 50, 'been': 49, 'very': 47, 'your': 47, 'out': 47, 'about': 46, 'back': 46, 'when': 45, 'one': 45, 'never': 45, 'were': 42, 'quality': 41, 'still': 41, 'more': 39, 'all': 39, 'It': 39, 'up': 37, 'pants': 36, '2': 36, 'sent': 35, 'we': 35, 'item': 35, 'than': 33, 'which': 33, 'has': 33, 'shipping': 33, 'any': 33, 'good': 32, 'days': 32, 'money': 32, 'what': 31, 'time': 31, 'email': 31, 'afte
# ...

# %% [markdown]
# ### TOP 10 keywords from worst comments
#
# 'Order' #112
# 'Received' #62
# 'Get' #59
# 'Service' #50
# 'Quality' #41
# 'Email' #31
# 'Product' #27
# 'Return' #27
# 'Website' #23
# 'Size' #23

# %% [markdown]
# ### Combine TOP 10 keywords

# %%
import pandas as pd
d1 = {'B20_Keywords': ['Order', 'Quality', 'Service', 'Received', 'Fit', 'Time', 'Size', 'Experience', 'Shipping', 'Fast'], 'B20_Times': [111, 85, 60, 49, 48, 43, 40, 38, 36, 31], 'W20_Keywords': ['Order', 'Received', 'Get', 'Service', 'Quality', 'Email', 'Product', 'Return', 'Website', 'Size'], 'W20_Times': [112, 62, 59, 50, 41, 31, 27, 27, 23, 23]}
df = pd.DataFrame(d1)
df
# Out:
#   B20_Keywords  B20_Times W20_Keywords  W20_Times
# 0        Order        111        Order        112
# 1      Quality         85     Received         62
# 2      Service         60          Get         59
# 3     Received         49      Service         50
# 4          Fit         48      Quality         41
# 5         Time         43        Email         31
# 6         Size         40      Product         27
# 7   Experience         38       Return         27
# 8     Shipping         36      Website         23
# 9         Fast         31         Size         23
