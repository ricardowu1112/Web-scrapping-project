# %% [markdown]
# ### Data Extraction with Beautiful Soup

# %%
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # The best 20 companies

# %%
response = requests.get('https://www.trustpilot.com/review/angeljackets.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_1 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/union22.co.uk')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_2 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/akrikks.com?page=2')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_3 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/hastamuerte.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_4 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/us.otrium.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_5 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/lebos.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_6 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/celticclothing.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_7 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/usakilts.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_8 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/newhorizonstrading.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_9 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/jaxxon.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_10 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/www.tailorstore.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_11 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/wordans.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_12 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/tagsafari.com?page=2')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_13 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/logansoflexington.com?page=4')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_14 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/suitsoutlets.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_15 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/shuuk.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_16 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/fanjackets.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_17 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/minoar.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_18 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/haspel.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_19 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
response = requests.get('https://www.trustpilot.com/review/luxire.com')
soup = BeautifulSoup(response.content, 'html.parser')
list_items = soup.find_all('div', {'styles_cardWrapper__LcCPA styles_show__HUXRb styles_reviewCard__9HxJJ'})
bcm_20 = [result.find(class_="typography_body-l__KUYFJ typography_appearance-default__AAY17 typography_color-black__5LYEn").get_text() for result in list_items]

# %%
best_combined = bcm_1 + bcm_2 + bcm_3 + bcm_4 + bcm_5 + bcm_6 + bcm_7 + bcm_8 + bcm_9 + bcm_10 + bcm_11 + bcm_12 + bcm_13 + bcm_14 + bcm_15 + bcm_16 + bcm_17 + bcm_18 + bcm_19 + bcm_20
best_combined
# Out:
# ['All this place does is double the price of Amazon products. I use the shop app which tells me who fulfils the order and yep, I can see that it ships straight from Amazon. I went onto amazon and searched and found the exact same jackets that I ordered from Angel Jackets but for HALF the price that Angel Jackets is selling them for. And on top of that, Angel Jackets charges a restocking fee - which Amazon does not! And you also have to pay return shipping. I really wish I had noticed this before ordering from Angel Jackets. I feel so ripped off right now.',
#  'The jacket purchased for my husband fits perfectly, couldn’t be happier and I do intend to be a repeat customer. Highly recommend Angel Jackets. Customer service was spot on as we were asked if we were purchasing the correct size .. we were and we did!!',
# ...
