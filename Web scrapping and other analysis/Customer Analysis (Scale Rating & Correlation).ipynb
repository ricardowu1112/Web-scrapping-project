# %%
from selenium import webdriver
from selenium.webdriver.support.ui import Select
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.support.ui import WebDriverWait
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains
import time

# %% [markdown]
# ### Browser Automation with Selenium & Data Extraction with Beautiful Soup for best rated 20 companies

# %%
driver = webdriver.Chrome('/Users/kaholi3/Downloads/chromedriver')
driver.get('https://www.trustpilot.com/')
# Out:
# /var/folders/bn/mxb8bm711w79zvytqtgfmjfr0000gn/T/ipykernel_3668/2727177390.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('/Users/kaholi3/Downloads/chromedriver')

# %%
from bs4 import BeautifulSoup
import requests

response = requests.get('https://www.trustpilot.com/categories/mens_clothing_store')
response.status_code

soup = BeautifulSoup(response.content, 'html.parser')
soup.prettify()
list_items = soup.find_all('div', {'class':'paper_paper__29o4A paper_outline__3rnlh card_card__2F_07 card_noPadding__1tkWv styles_wrapper__2QC-c'})

company_name = [result.find(class_="typography_heading-xs__D8ZZo").get_text() for result in list_items]
trust_score = [result.find(class_="typography_appearance-subtle__2GxHy").get_text().split('|')[0] for result in list_items]
no_of_reviews = [result.find(class_="typography_appearance-subtle__2GxHy").get_text().split('|')[1] for result in list_items]

cloth_store = pd.DataFrame({'Company_Name': company_name, 'Trust_Score': trust_score, 'No_of_Reviews': no_of_reviews})
cl = cloth_store.convert_dtypes()

cl['TrustScore'] = cl['Trust_Score'].apply(lambda i: i.translate({ord(i): None for i in 'TrustScore'}))
cl['TrustScore'] = cl['TrustScore'].astype(str).astype(float)

cl['No.Reviews'] = cl['No_of_Reviews'].apply(lambda i: i.translate({ord(i): None for i in 'reviews'}))
cl['No.Reviews'] = cl['No.Reviews'].apply(lambda i: i.translate({ord(i): None for i in ','}))
cl['No.Reviews'] = cl['No.Reviews'].astype(str).astype(int)

cl
# Out:
#             Company_Name     Trust_Score   No_of_Reviews  TrustScore  \
# 0               Union 22  TrustScore 4.9     505 reviews         4.9
# 1            A.K. RIKK's  TrustScore 4.9     282 reviews         4.9
# 2            Hastamuerte  TrustScore 4.8     974 reviews         4.8
# 3                 Otrium  TrustScore 4.8     929 reviews         4.8
# 4           Angeljackets  TrustScore 4.8     750 reviews         4.8
# 5                 Lebo's  TrustScore 4.8     746 reviews         4.8
# 6     CelticClothing.com  TrustScore 4.8     370 reviews         4.8
# 7              USA Kilts  TrustScore 4.8     205 reviews         4.8
# 8   New Horizons Trading  TrustScore 4.8      60 reviews         4.8
# 9                 JAXXON  TrustScore 4.7  30,316 reviews         4.7
# 10          Tailor Store  TrustScore 4.7   1,788 reviews         4.7
# 11           Wordans USA  TrustScore 4.7   1,522 reviews         4.7
# 12            TAG Safari  TrustScore 4.7     835 reviews         4.7
# 13  Logan's of Lexington  TrustScore 4.7     832 reviews         4.7
# 14         Suits Outlets  TrustScore 4.7     568 reviews         4.7
# 15                 Shuuk  TrustScore 4.7     461 reviews         4.7
# 16           Fan Jackets  TrustScore 4.7     243 reviews         4.7
# 17                MINOAR  TrustScore 4.7      47 reviews         4.7
# 18                Haspel  TrustScore 4.6     344 reviews         4.6
# 19            Luxire.com  TrustScore 4.6      54 reviews         4.6
#
#     No.Reviews
# 0          505
# 1          282
# 2          974
# 3          929
# 4          750
# 5          746
# 6          370
# 7          205
# 8           60
# 9        30316
# 10        1788
# 11        1522
# 12         835
# 13         832
# 14         568
# 15         461
# 16         243
# 17          47
# 18         344
# 19          54

# %% [markdown]
# ### Browser Automation with Selenium & Data Extraction with Beautiful Soup for worst rated 20 companies

# %%
response = requests.get('https://www.trustpilot.com/categories/mens_clothing_store?page=12')
response.status_code

soup = BeautifulSoup(response.content, 'html.parser')
soup.prettify()
list_items = soup.find_all('div', {'class':'paper_paper__29o4A paper_outline__3rnlh card_card__2F_07 card_noPadding__1tkWv styles_wrapper__2QC-c'})

company_name = [result.find(class_="typography_heading-xs__D8ZZo").get_text() for result in list_items]
trust_score = [result.find(class_="typography_appearance-subtle__2GxHy").get_text().split('|')[0] for result in list_items]
no_of_reviews = [result.find(class_="typography_appearance-subtle__2GxHy").get_text().split('|')[1] for result in list_items]

cloth_store2 = pd.DataFrame({'Company_Name': company_name, 'Trust_Score': trust_score, 'No_of_Reviews': no_of_reviews})
cl2 = cloth_store2.convert_dtypes()

cl2['TrustScore'] = cl2['Trust_Score'].apply(lambda i: i.translate({ord(i): None for i in 'TrustScore'}))
cl2['TrustScore'] = cl2['TrustScore'].astype(str).astype(float)

cl2['No.Reviews'] = cl2['No_of_Reviews'].apply(lambda i: i.translate({ord(i): None for i in 'reviews'}))
cl2['No.Reviews'] = cl2['No.Reviews'].apply(lambda i: i.translate({ord(i): None for i in ','}))
cl2['No.Reviews'] = cl2['No.Reviews'].astype(str).astype(int)

cl2
# Out:
#                Company_Name     Trust_Score  No_of_Reviews  TrustScore  \
# 0                  Junkeeri  TrustScore 3.2      1 reviews         3.2
# 1             BESPOKE DAILY  TrustScore 3.2      1 reviews         3.2
# 2                     WINGS  TrustScore 3.1      9 reviews         3.1
# 3                   Outworq  TrustScore 3.1      6 reviews         3.1
# 4                  Aaashirt  TrustScore 3.0     60 reviews         3.0
# 5                   Zartoni  TrustScore 2.9    103 reviews         2.9
# 6               JERSEY LOCO  TrustScore 2.9     63 reviews         2.9
# 7                  Birddogs  TrustScore 2.9      8 reviews         2.9
# 8           BAOBAB Clothing  TrustScore 2.9      8 reviews         2.9
# 9              Ten Thousand  TrustScore 2.8     72 reviews         2.8
# 10                   Gwen's  TrustScore 2.8      6 reviews         2.8
# 11          WorldSoccerShop  TrustScore 2.6  1,246 reviews         2.6
# 12             Leathersclub  TrustScore 2.6      7 reviews         2.6
# 13  Klein, Epstein & Parker  TrustScore 2.5     37 reviews         2.5
# 14                     Giga  TrustScore 2.5     17 reviews         2.5
# 15                    Quinn  TrustScore 2.5     12 reviews         2.5
# 16      Historical Emporium  TrustScore 2.5     10 reviews         2.5
# 17           BeltOutlet.com  TrustScore 2.5      5 reviews         2.5
# 18             Matchutailor  TrustScore 2.4     44 reviews         2.4
# 19               Public Rec  TrustScore 2.3    212 reviews         2.3
#
#     No.Reviews
# 0            1
# 1            1
# 2            9
# 3            6
# 4           60
# 5          103
# 6           63
# 7            8
# 8            8
# 9           72
# 10           6
# 11        1246
# 12           7
# 13          37
# 14          17
# 15          12
# 16          10
# 17           5
# 18          44
# 19         212

# %% [markdown]
# ### Concatenating best 20 & worst 20 dataframes

# %%
frames = [cl, cl2]
  
result = pd.concat(frames)
display(result)
# Out:
#                Company_Name     Trust_Score   No_of_Reviews  TrustScore  \
# 0                  Union 22  TrustScore 4.9     505 reviews         4.9
# 1               A.K. RIKK's  TrustScore 4.9     282 reviews         4.9
# 2               Hastamuerte  TrustScore 4.8     974 reviews         4.8
# 3                    Otrium  TrustScore 4.8     929 reviews         4.8
# 4              Angeljackets  TrustScore 4.8     750 reviews         4.8
# 5                    Lebo's  TrustScore 4.8     746 reviews         4.8
# 6        CelticClothing.com  TrustScore 4.8     370 reviews         4.8
# 7                 USA Kilts  TrustScore 4.8     205 reviews         4.8
# 8      New Horizons Trading  TrustScore 4.8      60 reviews         4.8
# 9                    JAXXON  TrustScore 4.7  30,316 reviews         4.7
# 10             Tailor Store  TrustScore 4.7   1,788 reviews         4.7
# 11              Wordans USA  TrustScore 4.7   1,522 reviews         4.7
# 12               TAG Safari  TrustScore 4.7     835 reviews         4.7
# 13     Logan's of Lexington  TrustScore 4.7     832 reviews         4.7
# 14            Suits Outlets  TrustScore 4.7     568 reviews         4.7
# 15                    Shuuk  TrustScore 4.7     461 reviews         4.7
# 16              Fan Jackets  TrustScore 4.7     243 reviews         4.7
# 17                   MINOAR  TrustScore 4.7      47 reviews         4.7
# 18                   Haspel  TrustScore 4.6     344 reviews         4.6
# 19               Luxire.com  TrustScore 4.6      54 reviews         4.6
# 0                  Junkeeri  TrustScore 3.2       1 reviews         3.2
# 1             BESPOKE DAILY  TrustScore 3.2       1 reviews         3.2
# 2                     WINGS  TrustScore 3.1       9 reviews         3.1
# 3                   Outworq  TrustScore 3.1       6 reviews         3.1
# 4                  Aaashirt  TrustScore 3.0      60 reviews         3.0
# 5                   Zartoni  TrustScore 2.9     103 reviews         2.9
# 6               JERSEY LOCO  TrustScore 2.9      63 reviews         2.9
# 7                  Birddogs  TrustScore 2.9       8 reviews         2.9
# 8           BAOBAB Clothing  TrustScore 2.9       8 reviews         2.9
# 9              Ten Thousand  TrustScore 2.8      72 reviews         2.8
# 10                   Gwen's  TrustScore 2.8       6 reviews         2.8
# 11          WorldSoccerShop  TrustScore 2.6   1,246 reviews         2.6
# 12             Leathersclub  TrustScore 2.6       7 reviews         2.6
# 13  Klein, Epstein & Parker  TrustScore 2.5      37 reviews         2.5
# 14                     Giga  TrustScore 2.5      17 reviews         2.5
# 15                    Quinn  TrustScore 2.5      12 reviews         2.5
# 16      Historical Emporium  TrustScore 2.5      10 reviews         2.5
# 17           BeltOutlet.com  TrustScore 2.5       5 reviews         2.5
# 18             Matchutailor  TrustScore 2.4      44 reviews         2.4
# 19               Public Rec  TrustScore 2.3     212 reviews         2.3
#
#     No.Reviews
# 0          505
# 1          282
# 2          974
# 3          929
# 4          750
# 5          746
# 6          370
# 7          205
# 8           60
# 9        30316
# 10        1788
# 11        1522
# 12         835
# 13         832
# 14         568
# 15         461
# 16         243
# 17          47
# 18         344
# 19          54
# 0            1
# 1            1
# 2            9
# 3            6
# 4           60
# 5          103
# 6           63
# 7            8
# 8            8
# 9           72
# 10           6
# 11        1246
# 12           7
# 13          37
# 14          17
# 15          12
# 16          10
# 17           5
# 18          44
# 19         212

# %% [markdown]
# ### Correlation between TrustScore & Reviews

# %%
print(result['TrustScore'].corr(result['No.Reviews']))
# Out:
# 0.19934361816888282
